# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
% matplotlib inline

# %%
AGW = pd.read_csv('AGW.csv',index_col=0,parse_dates=True)

# %%
AGW
# Out:
#                      stockVWAP  futureVWAP  stockAverageBidPrice  \
# 2017-01-25 09:17:00    134.248     134.664               134.046
# 2017-01-25 09:18:00    134.231     134.589               134.009
# 2017-01-25 09:19:00    134.177     134.550               134.061
# 2017-01-25 09:20:00    134.276     134.604               134.150
# 2017-01-25 09:21:00    134.414     134.819               134.363
# 2017-01-25 09:22:00    134.379     134.769               134.225
# 2017-01-25 09:23:00    134.370     134.746               134.238
# 2017-01-25 09:24:00    134.372     134.753               134.236
# 2017-01-25 09:25:00    134.522     134.922               134.257
# 2017-01-25 09:26:00    134.485     134.983               134.346
# 2017-01-25 09:27:00    134.694     135.219               134.579
# 2017-01-25 09:28:00    134.623     135.113               134.486
# 2017-01-25 09:29:00    134.595     135.064               134.328
# ...

# %%
AGW['Y'].plot(figsize=(18,12))
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
type(AGW)
# Out:
# pandas.core.frame.DataFrame

# %%
AGW.iloc[]
# Out:
# stockVWAP                  1.345300e+02
# futureVWAP                 1.349480e+02
# stockAverageBidPrice       1.342490e+02
# stockAverageAskPrice       1.346610e+02
# futureAverageBidPrice      1.346950e+02
# futureAverageAskPrice      1.350830e+02
# stockTopBidPrice           1.344000e+02
# stockTopAskPrice           1.345500e+02
# futureTopBidPrice          1.348500e+02
# futureTopAskPrice          1.350000e+02
# stockNextBidPrice          1.343500e+02
# stockNextAskPrice          1.346000e+02
# futureNextBidPrice         1.348000e+02
# futureNextAskPrice         1.350500e+02
# stockTopBidVol             1.872000e+03
# stockTopAskVol             5.193000e+03
# futureTopBidVol            1.800000e+04
# futureTopAskVol            2.700000e+04
# stockNextBidVol            1.602000e+03
# stockNextAskVol            1.622000e+03
# futureNextBidVol           9.000000e+03
# futureNextAskVol           9.000000e+03
# stockTotalBidVol           5.008700e+04
# ...
