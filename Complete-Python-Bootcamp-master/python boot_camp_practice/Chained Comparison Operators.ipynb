# %% [markdown]
# # Chained Comparison Operators

# %%
1 < 2
# Out:
# True

# %%
2 < 3
# Out:
# True

# %%
1 < 2 < 3
# Out:
# True

# %%
1 < 2 and 2 < 3
# Out:
# True

# %%
1 < 3
# Out:
# True

# %%
3 > 2
# Out:
# True

# %%
1 < 3 > 2
# Out:
# True

# %%
1 < 3 and 3 > 2
# Out:
# True

# %%
1 == 2
# Out:
# False

# %%
2 < 3
# Out:
# True

# %%
1 == 2 or 2 > 1
# Out:
# True

# %%
1 == 1 or 100 == 1
# Out:
# True
